# %%
#Normalization 
#Xnorm = (X - Xmin)/(Xmax - Xmin)

# %%
#Load the file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-22790830-46c3-4ed8-ae7a-975336a5c2b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-22790830-46c3-4ed8-ae7a-975336a5c2b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wine.data.csv to wine.data (1).csv

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("wine.data.csv",usecols=[0,1,2])
df_Norm = df
df_Norm.head()

sns.displot(df_Norm[['Alcohol','Malic acid']])

# %%
from sklearn.preprocessing import MinMaxScaler
# initialising the MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
df_Norm[['Alcohol','Malic acid']] = scaler.fit_transform(df_Norm[['Alcohol','Malic acid']])
df_Norm.head()
sns.displot(df_Norm[['Alcohol','Malic acid']])

# %%
#Standard Deviation
from sklearn.preprocessing import StandardScaler
scaling = StandardScaler()
df_StdDev = df

# %%
df_StdDev[['Alcohol','Malic acid']] = scaler.fit_transform(df_StdDev[['Alcohol','Malic acid']])
df_StdDev.head()
sns.displot(df_StdDev[['Alcohol','Malic acid']])
