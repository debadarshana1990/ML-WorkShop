# %%
import pandas as pd
import numpy as np

# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns
#import the dataset
from google.colab import files
dataset = files.upload()
# Out:
#      <input type="file" id="files-53b6a0b1-137b-40a3-862b-be26460d26fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53b6a0b1-137b-40a3-862b-be26460d26fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diabetes.csv to diabetes (1).csv

# %%
#print the datset and check for missing values
#create a dataframe and read the CSV
dataset = pd.read_csv("diabetes.csv")
#pd.set_option('display.max_rows', dataset.shape[0]+1)
dataset
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# 5              5      116  ...   30        0
# 6              3       78  ...   26        1
# 7             10      115  ...   29        0
# 8              2      197  ...   53        1
# 9              8      125  ...   54        1
# 10             4      110  ...   30        0
# 11            10      168  ...   34        1
# 12            10      139  ...   57        0
# 13             1      189  ...   59        1
# 14             5      166  ...   51        1
# 15             7      100  ...   32        1
# 16             0      118  ...   31        1
# 17             7      107  ...   31        1
# 18             1      103  ...   33        0
# 19             1      115  ...   32        1
# ...

# %%
#Check for missing values
#dataset.isnull()
dataset.isnull().any(axis = 1).sum()
# Out:
# 0

# %%
#Above line of code provides  the total number of rows with at least one missing data. It's 0 ,seems no missing data
#However, there are 0 values for Glucose, BllodPressure, SkinThickness, Insulin, BMI , Need to be corrected
temp_df = dataset.drop(["Pregnancies","Outcome"],axis = 1)
temp_df
medians = temp_df.median()
print("medians",medians)
df = temp_df.replace(0,medians)
df["Pregnancies"] = dataset["Pregnancies"]
df["Outcome"] = dataset["Outcome"]
df
# Out:
# medians Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# dtype: float64
#      Glucose  BloodPressure  SkinThickness  ...  Age  Pregnancies  Outcome
# 0        148             72             35  ...   50            6        1
# 1         85             66             29  ...   31            1        0
# 2        183             64             23  ...   32            8        1
# 3         89             66             23  ...   21            1        0
# 4        137             40             35  ...   33            0        1
# 5        116             74             23  ...   30            5        0
# 6         78             50             32  ...   26            3        1
# 7        115             72             23  ...   29           10        0
# ...

# %%
#Co-relation 
corelation = df.corr()
corelation
# Out:
#                            Glucose  BloodPressure  ...  Pregnancies   Outcome
# Glucose                   1.000000       0.218937  ...     0.128213  0.492782
# BloodPressure             0.218937       1.000000  ...     0.208615  0.165723
# SkinThickness             0.172143       0.147809  ...     0.032568  0.189065
# Insulin                   0.357573      -0.028721  ...    -0.055697  0.148457
# BMI                       0.231400       0.281132  ...     0.021546  0.312249
# DiabetesPedigreeFunction  0.137327      -0.002378  ...    -0.033523  0.173844
# Age                       0.266909       0.324915  ...     0.544341  0.238356
# Pregnancies               0.128213       0.208615  ...     1.000000  0.221898
# Outcome                   0.492782       0.165723  ...     0.221898  1.000000
#
# [9 rows x 9 columns]

# %%
#comment on corelation
# outcome is positively corelated to Glucose feature.
# Age & no. of pregencies have positive corelation.
# BMI & Skin thickness has positive corelation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df["Glucose"].plot(kind = 'density')
print("Glucose Skew:",df["Glucose"].skew())
# Out:
# Glucose Skew: 0.5355873034111183

# %%
df["BloodPressure"].plot(kind = 'density')
print("BloodPressure Skew:",df["BloodPressure"].skew())
# Out:
# BloodPressure Skew: 0.1418850201030565

# %%
df["SkinThickness"].plot(kind = 'density')
print("SkinThickness Skew:",df["SkinThickness"].skew())
# Out:
# SkinThickness Skew: 1.2230571171743103

# %%
df["Insulin"].plot(kind = 'density')
print("Insulin Skew:",df["Insulin"].skew())
# Out:
# Insulin Skew: 2.693180713015471

# %%
df["BMI"].plot(kind = 'density')
print("BMI Skew:",df["BMI"].skew())
# Out:
# BMI Skew: 0.6010587212883255

# %%
df["DiabetesPedigreeFunction"].plot(kind = 'density')
print("DiabetesPedigreeFunction Skew:",df["DiabetesPedigreeFunction"].skew())
# Out:
# DiabetesPedigreeFunction Skew: 1.919911066307204

# %%
df["Age"].plot(kind = 'density')
print("Age Skew:",df["Age"].skew())
# Out:
# Age Skew: 1.1295967011444805

# %%
df["Pregnancies"].plot(kind = 'density')
print("Pregnancies Skew:",df["Pregnancies"].skew())
# Out:
# Pregnancies Skew: 0.9016739791518588

# %%
#Box plot
plt.boxplot(df["Age"])
fig = plt.figure(figsize =(10, 7))
plt.show()

# %%
df.head(2)
plt.boxplot(df["Age"])
fig = plt.figure(figsize =(10, 7))
plt.show()

plt.boxplot(df["Glucose"])
fig = plt.figure(figsize =(10, 7))
plt.show()

plt.boxplot(df["BloodPressure"])
fig = plt.figure(figsize =(10, 7))
plt.show()

plt.boxplot(df["SkinThickness"])
fig = plt.figure(figsize =(10, 7))
plt.show()

plt.boxplot(df["Insulin"])
fig = plt.figure(figsize =(10, 7))
plt.show()

plt.boxplot(df["BMI"])
fig = plt.figure(figsize =(10, 7))
plt.show()

plt.boxplot(df["DiabetesPedigreeFunction"])
fig = plt.figure(figsize =(10, 7))
plt.show()

plt.boxplot(df["Pregnancies"])
fig = plt.figure(figsize =(10, 7))
plt.show()

# %%
#Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
#Feature Selection

feature_cols = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI','DiabetesPedigreeFunction','Age','Pregnancies']
x = df[feature_cols] # Features
y = df.Outcome # Target variable

# %%
#split datset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# import the metrics class
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# Accuracy: 0.70995670995671
# Precision: 0.6125
# Recall: 0.5764705882352941
# array([[115,  31],
#        [ 36,  49]])

# %%
#ROC Curve
y_pred_proba = clf.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
#AUC score for the case is 0.68. AUC score 1 represents a correct classifier and less than 0.5 is a not-usable classifier

# %%
pip install graphviz

# %%
pip install pydotplus

# %%
from sklearn.tree import export_graphviz
#from sklearn.externals.six import StringIO 
from six import StringIO 
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())

# %%
#Logistic Regrssion
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression(solver='lbfgs', max_iter=1000)

# %%
# fit the model with data
logreg.fit(x_train,y_train)

#
y_pred=logreg.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.7748917748917749
# Precision: 0.7538461538461538
# Recall: 0.5764705882352941

# %%
# import the metrics class
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[130,  16],
#        [ 36,  49]])

# %%
y_pred_proba = logreg.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
#AUC score for the case is 0.87 . AUC score 1 represents a correct classifier and less than 0.5 is a not-usable classifier

# %%
#Naive Bayes-Classifier
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train, y_train)
y_pred  =  classifier.predict(x_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.7619047619047619
# Precision: 0.6875
# Recall: 0.6470588235294118

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[121,  25],
#        [ 30,  55]])

# %%
y_pred_proba = classifier.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
##AUC score for the case is 0.85. AUC score 1 represents a correct classifier and less than 0.5 is a not-usable classifier
